# %% [markdown]
# # Customer Segmentation using RFM Analysis
#
# This notebook performs RFM (Recency, Frequency, Monetary) customer segmentation to classify customers based on their purchasing behavior.
#
# **RFM Framework:**
# - **Recency (R)**: How recently a customer made a purchase
# - **Frequency (F)**: How often a customer makes purchases
# - **Monetary (M)**: How much money a customer spends
#
# Customers are scored 1-5 on each dimension and segmented into actionable groups for targeted marketing strategies.

# %%
rfm['Segment'].value_counts().plot(kind='bar', title="Customer Segments")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 rfm['Segment'].value_counts().plot(kind='bar', title="Customer Segments")
#
# NameError: name 'rfm' is not defined

# %%
rfm.groupby('Segment')['Monetary'].sum().sort_values(ascending=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 rfm.groupby('Segment')['Monetary'].sum().sort_values(ascending=False)
#
# NameError: name 'rfm' is not defined

# %%
rfm['Segment'].value_counts()

# %%
def segment_customer(row):
    if row['R_score'] == 5 and row['F_score'] >= 4:
        return 'Champions'
    elif row['F_score'] >= 4:
        return 'Loyal'
    elif row['R_score'] >= 3:
        return 'Potential Loyalist'
    elif row['R_score'] == 2:
        return 'At Risk'
    else:
        return 'Lost'


rfm['Segment'] = rfm.apply(segment_customer, axis=1)

# %%
rfm['RFM_Score'] = (
    rfm['R_score'].astype(str) +
    rfm['F_score'].astype(str) +
    rfm['M_score'].astype(str)
)

# %%
rfm['R_score'] = pd.qcut(rfm['Recency'], 5, labels=[5,4,3,2,1])
rfm['F_score'] = pd.qcut(rfm['Frequency'].rank(method='first'), 5, labels=[1,2,3,4,5])
rfm['M_score'] = pd.qcut(rfm['Monetary'], 5, labels=[1,2,3,4,5])

# %%
import datetime

today_date = orders['order_date'].max()

rfm = orders.groupby('customer_id').agg({
    'order_date': lambda x: (today_date - x.max()).days,  # Recency
    'order_id': 'count',                                 # Frequency
    'revenue': 'sum'                                     # Monetary
})

rfm.columns = ['Recency', 'Frequency', 'Monetary']
rfm = rfm.reset_index()

# %%
orders['order_date'] = pd.to_datetime(orders['order_date'])

# %%
validate_dataframe(orders, "Orders")

# %%
orders = pd.read_csv("../data/processed/orders.csv")

# %%
import sys
import os
sys.path.append(os.path.abspath("../"))

import pandas as pd
from src.validation_engine import validate_dataframe

# %% [markdown]
# ## Key Insights Achieved
#
# ### Customer Segment Distribution
# - **Champions**: High-value customers who purchase recently, frequently, and spend the most
# - **Loyal**: Customers who purchase frequently but may not be the most recent
# - **Potential Loyalists**: Recent customers with moderate frequency and spending
# - **At Risk**: Customers who haven't purchased recently but have moderate history
# - **Lost**: Customers with low recency, frequency, and monetary value
#
# ### Business Applications
# - **Targeted Marketing**: Focus retention efforts on "At Risk" customers
# - **Personalization**: Offer premium services to "Champions"
# - **Re-engagement**: Develop campaigns for "Lost" customers
# - **Growth Strategy**: Nurture "Potential Loyalists" to increase loyalty
#
# ### Revenue Impact
# - Top segments by revenue: Champions typically generate the highest revenue
# - CLV Correlation: Higher RFM scores correlate with higher customer lifetime value
# - Retention Focus: Preventing customers from moving to lower segments can significantly impact revenue
